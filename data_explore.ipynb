# %%
from typing import List

import numpy as np
import pandas as pd

import pickle


from sklearn.cluster import KMeans, MiniBatchKMeans

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
def convert_semanticID_to_text(hie_id: List[int]) -> str:
    """Convert the generated hierarchical semantic id to text for training
       eg. [2, 5, 9, 5, 52] --> "2 5 9 5 52"
    
    Arguments:
      :hie_id - List[int]: the hierarchical semantic id for a single passage
    return:
      :str_id - str: the id with str format 
    """
    str_id_cand = []
    for sem_i in hie_id:
        str_id_cand.append(str(sem_i))
    return " ".join(str_id_cand)

def create_structured_semantic_id(
            img_emb_path: str="flickr-30k/figures_repr_mat.npy",
            k: int=5,
            c: int=30,
            emb_dim: int=768,
            cluster_bsz: int=int(1e3),
    ):
        """Create the structured semantic ids from data representation
        
        Args:
            psg_emb_path(str): the path of data representation. It shoule
                be loaded as a numpy.array format
            k(int): the number of clusters in clustering process
            c(int): the maximum number of leaf cluster
            emb_dim(int): dim of data representation
            cluster_bsz(int): batch size of KMeans clustering
        """
        
        # load passage_embedding npy file
        with open(img_emb_path, 'rb') as f:
            X = np.load(f, allow_pickle=True)

        kmeans = KMeans(
            n_clusters=k,
            max_iter=500,
            n_init=100,
            init='k-means++',
            tol=1e-6,
            verbose=20
        )

        mini_kmeans = MiniBatchKMeans(
            n_clusters=k,
            max_iter=300,
            n_init=100,
            init='k-means++',
            batch_size=cluster_bsz,
            reassignment_ratio=0.01,
            max_no_improvement=50,
            tol=1e-7,
            verbose=1
        )

        # use a list to store generated structured semantic ids
        semantic_id_list = []

        def classify_recursion(x_data_pos):
            if x_data_pos.shape[0] <= c:
                if x_data_pos.shape[0] == 1:
                    return
                for idx, pos in enumerate(x_data_pos):
                    semantic_id_list[pos].append(idx)
                return

            temp_data = np.zeros((x_data_pos.shape[0], emb_dim))
            for idx, pos in enumerate(x_data_pos):
                temp_data[idx, :] = X[pos]

            if x_data_pos.shape[0] >= cluster_bsz:
                pred = mini_kmeans.fit_predict(temp_data)
            else:
                pred = kmeans.fit_predict(temp_data)

            for i in range(k):
                pos_lists = []
                for id_, class_ in enumerate(pred):
                    if class_ == i:
                        pos_lists.append(x_data_pos[id_])
                        semantic_id_list[x_data_pos[id_]].append(i)
                classify_recursion(np.array(pos_lists))
            return

        print('Start First Clustering')
        pred = kmeans.fit_predict(X)
        print(pred.shape)  # int 0-9 for each vector
        print(kmeans.n_iter_)

        for class_ in pred:
            semantic_id_list.append([class_])

        print('Start Recursively Clustering...')
        for i in range(k):
            print(i, "th cluster")
            pos_lists = []
            for id_, class_ in enumerate(pred):
                if class_ == i:
                    pos_lists.append(id_)
            classify_recursion(np.array(pos_lists))
        print('Complete!')

        # This process is very time-consuming, so it will be better to save the
        # intermediate result to disk
        with open("flickr-30k/new_ids_list.pkl", "wb") as f:
            pickle.dump(semantic_id_list, f)

        old2new_id_mapper = {}
        new2old_id_mapper = {}
        
        # load old id
        with open("flickr-30k/old_ids_list.pkl", "rb") as f:
            old_id_list = pickle.load(f)
        # load new id
        with open("flickr-30k/new_ids_list.pkl", "rb") as f:
            new_id_list = pickle.load(f)

        # generate old2new_id_mapper
        for i in range(len(old_id_list)):
            old2new_id_mapper[old_id_list[i]] = convert_semanticID_to_text(new_id_list[i])
        # generate new2old_id_mapper
        for old, new in old2new_id_mapper.items():
            new2old_id_mapper[new] = old

        # save to disk
        with open(f"flickr-30k/old2new_id_mapper_k{k}_c{c}.pkl", "wb") as f:
            pickle.dump(old2new_id_mapper, f)
        with open(f"flickr-30k/new2old_id_mapper_k{k}_c{c}.pkl", "wb") as f:
            pickle.dump(new2old_id_mapper, f)

create_structured_semantic_id()
# Out:
# Start First Clustering
# Initialization complete
# Iteration 0, inertia 35924.15234375.
# Initialization complete
# Iteration 1, inertia 35831.92578125.
# Initialization complete
# Iteration 2, inertia 35831.92578125.
# Initialization complete
# Iteration 3, inertia 35832.1796875.
# Initialization complete
# Iteration 4, inertia 35924.15234375.
# Initialization complete
# Iteration 5, inertia 35924.15234375.
# Initialization complete
# Iteration 6, inertia 35832.0078125.
# Initialization complete
# Iteration 7, inertia 35831.609375.
# Initialization complete
# Iteration 8, inertia 35924.15234375.
# Initialization complete
# Iteration 9, inertia 35924.15234375.
# Initialization complete
# Iteration 10, inertia 35922.73046875.
# Initialization complete
# Iteration 11, inertia 35831.92578125.
# Initialization complete
# Iteration 12, inertia 35924.15234375.
# Initialization complete
# Iteration 13, inertia 35924.15234375.
# Initialization complete
# Iteration 14, inertia 35831.73828125.
# Initialization complete
# Iteration 15, inertia 35924.15234375.
# Initialization complete
# Iteration 16, inertia 35831.92578125.
# Initialization complete
# Iteration 17, inertia 35832.1796875.
# Initialization complete
# Iteration 18, inertia 35924.15234375.
# Initialization complete
# Iteration 19, inertia 35831.5234375.
# Initialization complete
# Iteration 20, inertia 35832.07421875.
# Initialization complete
# Iteration 21, inertia 35924.15234375.
# Initialization complete
# Iteration 22, inertia 35924.14453125.
# Initialization complete
# Iteration 23, inertia 35923.921875.
# Initialization complete
# Iteration 24, inertia 35923.30078125.
# Initialization complete
# Iteration 25, inertia 35832.1796875.
# Initialization complete
# Iteration 26, inertia 35923.92578125.
# Initialization complete
# Iteration 27, inertia 35923.96484375.
# Initialization complete
# Iteration 28, inertia 35924.15234375.
# Initialization complete
# Iteration 29, inertia 35831.90234375.
# Initialization complete
# Iteration 30, inertia 35924.15234375.
# Initialization complete
# Iteration 31, inertia 35832.1796875.
# Initialization complete
# Iteration 32, inertia 35831.92578125.
# Initialization complete
# Iteration 33, inertia 35923.171875.
# Initialization complete
# Iteration 34, inertia 35924.15234375.
# Initialization complete
# Iteration 35, inertia 35832.03125.
# Initialization complete
# Iteration 36, inertia 35922.28515625.
# Initialization complete
# Iteration 37, inertia 35924.15234375.
# Initialization complete
# Iteration 38, inertia 35831.92578125.
# Initialization complete
# Iteration 39, inertia 35831.92578125.
# Initialization complete
# Iteration 40, inertia 35923.921875.
# Initialization complete
# Iteration 41, inertia 35831.92578125.
# Initialization complete
# Iteration 42, inertia 35922.72265625.
# Initialization complete
# Iteration 43, inertia 35832.2265625.
# Initialization complete
# Iteration 44, inertia 35831.92578125.
# Initialization complete
# Iteration 45, inertia 35832.03125.
# Initialization complete
# Iteration 46, inertia 35832.1796875.
# Initialization complete
# Iteration 47, inertia 35924.15234375.
# Initialization complete
# Iteration 48, inertia 35832.16015625.
# Initialization complete
# Iteration 49, inertia 35923.1171875.
# Initialization complete
# Iteration 50, inertia 35942.1015625.
# Initialization complete
# Iteration 51, inertia 35924.15234375.
# Initialization complete
# Iteration 52, inertia 35924.15234375.
# Initialization complete
# Iteration 53, inertia 35832.03125.
# Initialization complete
# Iteration 54, inertia 35924.15234375.
# Initialization complete
# Iteration 55, inertia 35923.171875.
# Initialization complete
# Iteration 56, inertia 35924.15234375.
# Initialization complete
# Iteration 57, inertia 35924.14453125.
# Initialization complete
# Iteration 58, inertia 35923.25.
# Initialization complete
# Iteration 59, inertia 35832.16015625.
# Initialization complete
# Iteration 60, inertia 35832.20703125.
# Initialization complete
# Iteration 61, inertia 35832.16015625.
# Initialization complete
# Iteration 62, inertia 35924.15234375.
# Initialization complete
# Iteration 63, inertia 35924.15234375.
# Initialization complete
# Iteration 64, inertia 35831.79296875.
# Initialization complete
# Iteration 65, inertia 35831.92578125.
# Initialization complete
# Iteration 66, inertia 35831.92578125.
# Initialization complete
# Iteration 67, inertia 35832.2265625.
# Initialization complete
# Iteration 68, inertia 35924.15234375.
# Initialization complete
# Iteration 69, inertia 35832.2265625.
# Initialization complete
# Iteration 70, inertia 35832.16015625.
# Initialization complete
# Iteration 71, inertia 35922.8046875.
# Initialization complete
# Iteration 72, inertia 35936.74609375.
# Initialization complete
# Iteration 73, inertia 35923.21484375.
# Initialization complete
# Iteration 74, inertia 35924.15234375.
# Initialization complete
# Iteration 75, inertia 35831.92578125.
# Initialization complete
# Iteration 76, inertia 35922.2578125.
# Initialization complete
# Iteration 77, inertia 35923.12890625.
# Initialization complete
# Iteration 78, inertia 35929.625.
# Initialization complete
# Iteration 79, inertia 35831.98828125.
# Initialization complete
# Iteration 80, inertia 35924.15234375.
# Initialization complete
# Iteration 81, inertia 35924.15234375.
# Initialization complete
# Iteration 82, inertia 35923.10546875.
# Initialization complete
# Iteration 83, inertia 35831.92578125.
# Initialization complete
# Iteration 84, inertia 35924.15234375.
# Initialization complete
# Iteration 85, inertia 35924.15234375.
# Initialization complete
# Iteration 86, inertia 35831.92578125.
# Initialization complete
# Iteration 87, inertia 35923.92578125.
# Initialization complete
# Iteration 88, inertia 35831.92578125.
# Initialization complete
# Iteration 89, inertia 35832.16015625.
# Initialization complete
# Iteration 90, inertia 35924.15234375.
# Initialization complete
# Iteration 91, inertia 35937.15234375.
# Initialization complete
# Iteration 92, inertia 35924.15234375.
# Initialization complete
# Iteration 93, inertia 35831.77734375.
# Initialization complete
# Iteration 94, inertia 35924.15234375.
# Initialization complete
# Iteration 95, inertia 35924.15234375.
# Initialization complete
# Iteration 96, inertia 35924.15234375.
# Initialization complete
# Iteration 97, inertia 35831.40625.
# Initialization complete
# Iteration 98, inertia 35924.15234375.
# Initialization complete
# Iteration 99, inertia 35831.92578125.
# (10000,)
# 24
# Start Recursively Clustering...
# 0 th cluster
# Init 1/100 with method k-means++
# Inertia for init 1/100: 6252.000727575892
# Init 2/100 with method k-means++
# c:\Users\jsfz\anaconda3\envs\pytorch17\lib\site-packages\sklearn\cluster\_kmeans.py:1044: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 3072 or by setting the environment variable OMP_NUM_THREADS=4
#   "MiniBatchKMeans is known to have a memory leak on "
# Inertia for init 2/100: 7071.84224962362
# Init 3/100 with method k-means++
# Inertia for init 3/100: 6380.491453894814
# Init 4/100 with method k-means++
# Inertia for init 4/100: 6329.060743705633
# Init 5/100 with method k-means++
# Inertia for init 5/100: 7120.824777234356
# Init 6/100 with method k-means++
# Inertia for init 6/100: 6064.05781549347
# Init 7/100 with method k-means++
# Inertia for init 7/100: 6553.93764421682
# Init 8/100 with method k-means++
# Inertia for init 8/100: 6422.038381949092
# Init 9/100 with method k-means++
# Inertia for init 9/100: 6692.573243501959
# Init 10/100 with method k-means++
# Inertia for init 10/100: 6262.972284837174
# Init 11/100 with method k-means++
# Inertia for init 11/100: 6186.16516689887
# Init 12/100 with method k-means++
# Inertia for init 12/100: 6492.353583005461
# Init 13/100 with method k-means++
# Inertia for init 13/100: 7308.873345553165
# Init 14/100 with method k-means++
# Inertia for init 14/100: 6059.293465259439
# Init 15/100 with method k-means++
# Inertia for init 15/100: 6019.461282970882
# Init 16/100 with method k-means++
# Inertia for init 16/100: 6708.103871942599
# Init 17/100 with method k-means++
# Inertia for init 17/100: 6110.126828984329
# Init 18/100 with method k-means++
# Inertia for init 18/100: 6168.066541545109
# Init 19/100 with method k-means++
# Inertia for init 19/100: 6512.447564490166
# Init 20/100 with method k-means++
# Inertia for init 20/100: 6473.238175899869
# Init 21/100 with method k-means++
# Inertia for init 21/100: 6916.492519659287
# Init 22/100 with method k-means++
# Inertia for init 22/100: 6756.60466463252
# Init 23/100 with method k-means++
# Inertia for init 23/100: 6105.162336553536
# Init 24/100 with method k-means++
# Inertia for init 24/100: 6559.196408167601
# Init 25/100 with method k-means++
# Inertia for init 25/100: 7301.53634732159
# Init 26/100 with method k-means++
# Inertia for init 26/100: 6174.802878493798
# Init 27/100 with method k-means++
# Inertia for init 27/100: 6441.302984595514
# Init 28/100 with method k-means++
# Inertia for init 28/100: 6015.8419878066115
# Init 29/100 with method k-means++
# Inertia for init 29/100: 6843.568284488969
# Init 30/100 with method k-means++
# Inertia for init 30/100: 6841.45022400314
# Init 31/100 with method k-means++
# Inertia for init 31/100: 7116.601291216177
# Init 32/100 with method k-means++
# Inertia for init 32/100: 7120.024734097447
# Init 33/100 with method k-means++
# Inertia for init 33/100: 6633.897292046589
# Init 34/100 with method k-means++
# Inertia for init 34/100: 5803.764141261891
# Init 35/100 with method k-means++
# Inertia for init 35/100: 7143.350685836241
# Init 36/100 with method k-means++
# Inertia for init 36/100: 7014.526852836154
# Init 37/100 with method k-means++
# Inertia for init 37/100: 7268.328979191994
# Init 38/100 with method k-means++
# Inertia for init 38/100: 7017.82374366772
# Init 39/100 with method k-means++
# Inertia for init 39/100: 6635.960525663243
# Init 40/100 with method k-means++
# Inertia for init 40/100: 6619.955674135255
# Init 41/100 with method k-means++
# Inertia for init 41/100: 6472.07928069814
# Init 42/100 with method k-means++
# Inertia for init 42/100: 6319.019827512778
# Init 43/100 with method k-means++
# Inertia for init 43/100: 6188.66379680388
# Init 44/100 with method k-means++
# Inertia for init 44/100: 5821.735934481801
# Init 45/100 with method k-means++
# Inertia for init 45/100: 6397.589597093152
# Init 46/100 with method k-means++
# Inertia for init 46/100: 6796.544243005907
# Init 47/100 with method k-means++
# Inertia for init 47/100: 6258.103770694311
# Init 48/100 with method k-means++
# Inertia for init 48/100: 5943.451075627209
# Init 49/100 with method k-means++
# Inertia for init 49/100: 6019.665375804118
# Init 50/100 with method k-means++
# Inertia for init 50/100: 6038.722179281787
# Init 51/100 with method k-means++
# Inertia for init 51/100: 6422.591120704111
# Init 52/100 with method k-means++
# Inertia for init 52/100: 6284.344453771245
# Init 53/100 with method k-means++
# Inertia for init 53/100: 6197.193293553738
# Init 54/100 with method k-means++
# Inertia for init 54/100: 6498.637945777709
# Init 55/100 with method k-means++
# Inertia for init 55/100: 6531.624604136866
# Init 56/100 with method k-means++
# Inertia for init 56/100: 6337.557555658224
# Init 57/100 with method k-means++
# Inertia for init 57/100: 6698.746738515064
# Init 58/100 with method k-means++
# Inertia for init 58/100: 7549.22749402859
# Init 59/100 with method k-means++
# Inertia for init 59/100: 7306.108941680236
# Init 60/100 with method k-means++
# Inertia for init 60/100: 6406.446969181352
# Init 61/100 with method k-means++
# Inertia for init 61/100: 7634.053323556032
# Init 62/100 with method k-means++
# Inertia for init 62/100: 6958.936504782427
# Init 63/100 with method k-means++
# Inertia for init 63/100: 6717.188434538044
# Init 64/100 with method k-means++
# Inertia for init 64/100: 6404.879529806631
# Init 65/100 with method k-means++
# Inertia for init 65/100: 8192.94356161055
# Init 66/100 with method k-means++
# Inertia for init 66/100: 6073.112539296526
# Init 67/100 with method k-means++
# Inertia for init 67/100: 6345.634824558248
# Init 68/100 with method k-means++
# Inertia for init 68/100: 6712.312986229936
# Init 69/100 with method k-means++
# Inertia for init 69/100: 6313.183539883594
# Init 70/100 with method k-means++
# Inertia for init 70/100: 7474.8308560280875
# Init 71/100 with method k-means++
# Inertia for init 71/100: 6653.498805120091
# Init 72/100 with method k-means++
# Inertia for init 72/100: 6416.989959904258
# Init 73/100 with method k-means++
# Inertia for init 73/100: 6835.585454735204
# Init 74/100 with method k-means++
# Inertia for init 74/100: 6625.786867691715
# Init 75/100 with method k-means++
# Inertia for init 75/100: 6591.142608139356
# Init 76/100 with method k-means++
# Inertia for init 76/100: 6378.240445483458
# Init 77/100 with method k-means++
# Inertia for init 77/100: 6370.463752593403
# Init 78/100 with method k-means++
# Inertia for init 78/100: 6841.274905388945
# Init 79/100 with method k-means++
# Inertia for init 79/100: 6781.265302095227
# Init 80/100 with method k-means++
# Inertia for init 80/100: 6466.220743484892
# Init 81/100 with method k-means++
# Inertia for init 81/100: 6556.886634811207
# Init 82/100 with method k-means++
# Inertia for init 82/100: 6994.505881169879
# Init 83/100 with method k-means++
# Inertia for init 83/100: 6828.02088890853
# Init 84/100 with method k-means++
# Inertia for init 84/100: 6489.776061291466
# Init 85/100 with method k-means++
# Inertia for init 85/100: 6374.853228715284
# Init 86/100 with method k-means++
# Inertia for init 86/100: 7201.738890739824
# Init 87/100 with method k-means++
# Inertia for init 87/100: 7118.732250864061
# Init 88/100 with method k-means++
# Inertia for init 88/100: 6400.322127136491
# Init 89/100 with method k-means++
# Inertia for init 89/100: 6054.876984390906
# Init 90/100 with method k-means++
# Inertia for init 90/100: 6916.79884111317
# Init 91/100 with method k-means++
# Inertia for init 91/100: 6736.7097243563785
# Init 92/100 with method k-means++
# Inertia for init 92/100: 5906.434431715374
# Init 93/100 with method k-means++
# Inertia for init 93/100: 6360.593790661506
# Init 94/100 with method k-means++
# Inertia for init 94/100: 6174.27510477947
# Init 95/100 with method k-means++
# Inertia for init 95/100: 6343.6231011623495
# Init 96/100 with method k-means++
# Inertia for init 96/100: 6545.985400042047
# Init 97/100 with method k-means++
# Inertia for init 97/100: 6817.952586998077
# Init 98/100 with method k-means++
# Inertia for init 98/100: 6612.620103767705
# Init 99/100 with method k-means++
# Inertia for init 99/100: 6726.79371753457
# Init 100/100 with method k-means++
# Inertia for init 100/100: 6403.984551151561
# Minibatch step 1/720: mean batch inertia: 2.409117362378726
# Minibatch step 2/720: mean batch inertia: 1.9573963372310437, ewa inertia: 1.9573963372310437
# Minibatch step 3/720: mean batch inertia: 1.8444596422865134, ewa inertia: 1.8633607877351817
# Minibatch step 4/720: mean batch inertia: 1.8180472810252846, ewa inertia: 1.825630973655334
# Minibatch step 5/720: mean batch inertia: 1.890056932629005, ewa inertia: 1.87927456980327
# Minibatch step 6/720: mean batch inertia: 1.9784236432582354, ewa inertia: 1.9618300014893362
# Minibatch step 7/720: mean batch inertia: 1.9186290252086773, ewa inertia: 1.9258591636203448
# Minibatch step 8/720: mean batch inertia: 1.8538950456690497, ewa inertia: 1.865938998798284
# Minibatch step 9/720: mean batch inertia: 1.8410312881039095, ewa inertia: 1.8451998558387714
# Minibatch step 10/720: mean batch inertia: 1.8443807900753806, ewa inertia: 1.844517869358013
# Minibatch step 11/720: mean batch inertia: 1.9229210949188023, ewa inertia: 1.9097994893087118
# Minibatch step 12/720: mean batch inertia: 1.8982930755141214, ewa inertia: 1.9002187950584284
# Minibatch step 13/720: mean batch inertia: 1.9087691625752947, ewa inertia: 1.9073381685112731
# Minibatch step 14/720: mean batch inertia: 1.8652398215390023, ewa inertia: 1.8722854233220383
# Minibatch step 15/720: mean batch inertia: 1.890215552892124, ewa inertia: 1.8872147568525013
# Minibatch step 16/720: mean batch inertia: 1.8471192695332486, ewa inertia: 1.8538296716574534
# Minibatch step 17/720: mean batch inertia: 1.8566934875976777, ewa inertia: 1.8562141978358249
# Minibatch step 18/720: mean batch inertia: 1.8492142142411225, ewa inertia: 1.850385735225748
# Minibatch step 19/720: mean batch inertia: 1.8879142911065128, ewa inertia: 1.8816334919957438
# Minibatch step 20/720: mean batch inertia: 1.9048907695108714, ewa inertia: 1.9009984191523863
# Minibatch step 21/720: mean batch inertia: 1.78622057737367, ewa inertia: 1.8054298581376351
# Minibatch step 22/720: mean batch inertia: 1.8270349292475199, ewa inertia: 1.8234190930334593
# Minibatch step 23/720: mean batch inertia: 1.7955542978251402, ewa inertia: 1.8002177648000544
# Minibatch step 24/720: mean batch inertia: 1.883392929215119, ewa inertia: 1.869472689375462
# Minibatch step 25/720: mean batch inertia: 1.8930944471291382, ewa inertia: 1.889141097163702
# Minibatch step 26/720: mean batch inertia: 1.8632078191232782, ewa inertia: 1.867548026355689
# Minibatch step 27/720: mean batch inertia: 1.8390617478914548, ewa inertia: 1.8438292266352607
# Minibatch step 28/720: mean batch inertia: 1.8862007420737097, ewa inertia: 1.8791094226706053
# Minibatch step 29/720: mean batch inertia: 1.8893294225256736, ewa inertia: 1.8876189979038012
# Minibatch step 30/720: mean batch inertia: 1.7869801503358136, ewa inertia: 1.803823121494153
# Minibatch step 31/720: mean batch inertia: 1.8155925818078145, ewa inertia: 1.813622838657901
# Minibatch step 32/720: mean batch inertia: 1.8701556974340756, ewa inertia: 1.8606943280635417
# Minibatch step 33/720: mean batch inertia: 1.769763326728451, ewa inertia: 1.7849815875680455
# Minibatch step 34/720: mean batch inertia: 1.892027739634455, ewa inertia: 1.874112438580876
# Minibatch step 35/720: mean batch inertia: 1.9099530800737134, ewa inertia: 1.9039547712143792
# Minibatch step 36/720: mean batch inertia: 1.9152952056922816, ewa inertia: 1.9133972645348643
# Minibatch step 37/720: mean batch inertia: 1.8854238180399228, ewa inertia: 1.8901054689520653
# Minibatch step 38/720: mean batch inertia: 1.8846973730128247, ewa inertia: 1.8856024748311322
# Minibatch step 39/720: mean batch inertia: 1.9964075775886183, ewa inertia: 1.9778631765442765
# Minibatch step 40/720: mean batch inertia: 1.7786505256083238, ewa inertia: 1.8119908610272468
# Minibatch step 41/720: mean batch inertia: 1.8160414720244051, ewa inertia: 1.8153635596093936
# Minibatch step 42/720: mean batch inertia: 1.8255642890269486, ewa inertia: 1.8238570895157673
# Minibatch step 43/720: mean batch inertia: 1.8903264484191258, ewa inertia: 1.8792021010922522
# Minibatch step 44/720: mean batch inertia: 1.9347030381952768, ewa inertia: 1.9254143717858612
# Minibatch step 45/720: mean batch inertia: 1.9258880154551041, ewa inertia: 1.92580874619822
# Minibatch step 46/720: mean batch inertia: 1.8287065593281442, ewa inertia: 1.8449576330674324
# Minibatch step 47/720: mean batch inertia: 1.9109722826480555, ewa inertia: 1.8999240357157448
# Minibatch step 48/720: mean batch inertia: 1.840715250427943, ewa inertia: 1.8506244642854353
# Minibatch step 49/720: mean batch inertia: 1.784609907322708, ewa inertia: 1.7956581387544381
# Minibatch step 50/720: mean batch inertia: 1.7730123312749384, ewa inertia: 1.776802345682415
# Minibatch step 51/720: mean batch inertia: 1.8625830734091018, ewa inertia: 1.8482267651051352
# Minibatch step 52/720: mean batch inertia: 1.8470192239190713, ewa inertia: 1.8472213186554567
# Minibatch step 53/720: mean batch inertia: 1.8127802039922536, ewa inertia: 1.8185442872955873
# Minibatch step 54/720: mean batch inertia: 1.8050176009266257, ewa inertia: 1.807281434365561
# Minibatch step 55/720: mean batch inertia: 1.8889990754861263, ewa inertia: 1.8753227675217354
# Minibatch step 56/720: mean batch inertia: 1.864360005078333, ewa inertia: 1.8661947388427993
# Minibatch step 57/720: mean batch inertia: 1.7731577844471564, ewa inertia: 1.7887284987132048
# Minibatch step 58/720: mean batch inertia: 1.8112375227986792, ewa inertia: 1.807470400532917
# Minibatch step 59/720: mean batch inertia: 1.8410242571715183, ewa inertia: 1.835408665843992
# Minibatch step 60/720: mean batch inertia: 1.8869349073562032, ewa inertia: 1.878311448118939
# Minibatch step 61/720: mean batch inertia: 1.9322329083507586, ewa inertia: 1.9232085840321942
# Minibatch step 62/720: mean batch inertia: 1.8647675360713527, ewa inertia: 1.8745482610006858
# Minibatch step 63/720: mean batch inertia: 1.8486788295755683, ewa inertia: 1.853008351404418
# Minibatch step 64/720: mean batch inertia: 1.8686055249366738, ewa inertia: 1.8659951736627494
# Minibatch step 65/720: mean batch inertia: 1.8393392209970665, ewa inertia: 1.8438003754398662
# Minibatch step 66/720: mean batch inertia: 1.9470925806159745, ewa inertia: 1.9298055421143943
# Minibatch step 67/720: mean batch inertia: 1.8419341687696047, ewa inertia: 1.8566403686382995
# Minibatch step 68/720: mean batch inertia: 1.8891914867592308, ewa inertia: 1.8837437142843703
# Minibatch step 69/720: mean batch inertia: 1.878239684289806, ewa inertia: 1.8791608416827346
# Minibatch step 70/720: mean batch inertia: 1.9272854097244645, ewa inertia: 1.9192312563719351
# Minibatch step 71/720: mean batch inertia: 1.7936270805784407, ewa inertia: 1.8146482623723559
# Minibatch step 72/720: mean batch inertia: 1.897715262756032, ewa inertia: 1.8838131253063077
# Minibatch step 73/720: mean batch inertia: 1.8535008140748286, ewa inertia: 1.858573898635634
# Minibatch step 74/720: mean batch inertia: 1.930623455257605, ewa inertia: 1.918565203066917
# Minibatch step 75/720: mean batch inertia: 1.9392197169334733, ewa inertia: 1.935762966486198
# Minibatch step 76/720: mean batch inertia: 1.9539043943634022, ewa inertia: 1.9508682353265012
# Minibatch step 77/720: mean batch inertia: 1.817690345871015, ewa inertia: 1.839979068419352
# Minibatch step 78/720: mean batch inertia: 1.798077488176511, ewa inertia: 1.805090158974855
# Minibatch step 79/720: mean batch inertia: 1.793309570895012, ewa inertia: 1.7952811763938032
# Minibatch step 80/720: mean batch inertia: 1.90450240971904, ewa inertia: 1.8862230859069062
# Minibatch step 81/720: mean batch inertia: 1.8754418115642921, ewa inertia: 1.8772461713834974
# Minibatch step 82/720: mean batch inertia: 1.8876727066030334, ewa inertia: 1.8859277161125032
# Minibatch step 83/720: mean batch inertia: 1.8560116134896318, ewa inertia: 1.8610183883665654
# Minibatch step 84/720: mean batch inertia: 1.9509011323996086, ewa inertia: 1.9358583084606895
# Minibatch step 85/720: mean batch inertia: 1.8302525757923838, ewa inertia: 1.847926807487912
# Minibatch step 86/720: mean batch inertia: 1.8458656674726568, ewa inertia: 1.8462106209639693
# Minibatch step 87/720: mean batch inertia: 1.8873262383634772, ewa inertia: 1.8804451067254249
# Minibatch step 88/720: mean batch inertia: 1.8879881176621336, ewa inertia: 1.8867257153321764
# Minibatch step 89/720: mean batch inertia: 1.8645357926166621, ewa inertia: 1.868249509907102
# Minibatch step 90/720: mean batch inertia: 1.8731276227738987, ewa inertia: 1.8723112192050178
# Minibatch step 91/720: mean batch inertia: 1.8634192688996523, ewa inertia: 1.8649074304411832
# Minibatch step 92/720: mean batch inertia: 1.8334713768667488, ewa inertia: 1.8387325315449015
# Minibatch step 93/720: mean batch inertia: 1.8676799804172697, ewa inertia: 1.8628353199482057
# Minibatch step 94/720: mean batch inertia: 1.8401479829263159, ewa inertia: 1.8439449477401375
# Minibatch step 95/720: mean batch inertia: 1.8144641418426686, ewa inertia: 1.819398065227674
# Minibatch step 96/720: mean batch inertia: 1.806054650973933, ewa inertia: 1.8082878118940013
# Minibatch step 97/720: mean batch inertia: 1.8178977282913134, ewa inertia: 1.8162894075620382
# Minibatch step 98/720: mean batch inertia: 1.8213964262951632, ewa inertia: 1.820541712918512
# Minibatch step 99/720: mean batch inertia: 1.808373098333124, ewa inertia: 1.8104096441546587
# Minibatch step 100/720: mean batch inertia: 1.872147833467993, ewa inertia: 1.8618152972048954
# Converged (lack of improvement in inertia) at step 100/720
# Initialization complete
# Iteration 0, inertia 550.5818100456037.
# Initialization complete
# Iteration 1, inertia 551.2793992019676.
# Initialization complete
# Iteration 2, inertia 560.8651671662236.
# Initialization complete
# Iteration 3, inertia 566.5986242016235.
# Initialization complete
# Iteration 4, inertia 556.5419601488085.
# Initialization complete
# Iteration 5, inertia 575.345111511369.
# Initialization complete
# Iteration 6, inertia 548.8035039094091.
# Initialization complete
# Iteration 7, inertia 571.5228142757666.
# Initialization complete
# Iteration 8, inertia 574.0645506674593.
# Initialization complete
# Iteration 9, inertia 566.9597248138202.
# Initialization complete
# Iteration 10, inertia 560.4891642837283.
# Initialization complete
# Iteration 11, inertia 558.3992532906065.
# Initialization complete
# Iteration 12, inertia 549.3735303476733.
# Initialization complete
# Iteration 13, inertia 550.9872754384666.
# Initialization complete
# Iteration 14, inertia 565.0348618549225.
# Initialization complete
# Iteration 15, inertia 550.3616787740618.
# Initialization complete
# Iteration 16, inertia 549.5602217805543.
# Initialization complete
# Iteration 17, inertia 558.6225470942543.
# Initialization complete
# Iteration 18, inertia 550.3627569940066.
# Initialization complete
# Iteration 19, inertia 550.2032296655566.
# Initialization complete
# Iteration 20, inertia 549.8299821469889.
# Initialization complete
# Iteration 21, inertia 549.569457316125.
# Initialization complete
# Iteration 22, inertia 560.8144872426288.
# Initialization complete
# Iteration 23, inertia 549.7906827054012.
# Initialization complete
# Iteration 24, inertia 551.6315090644669.
# Initialization complete
# Iteration 25, inertia 557.9924777564761.
# Initialization complete
# Iteration 26, inertia 552.5886313537802.
# Initialization complete
# Iteration 27, inertia 556.3651832024526.
# Initialization complete
# Iteration 28, inertia 550.1763124518233.
# Initialization complete
# Iteration 29, inertia 566.5616149153109.
# Initialization complete
# Iteration 30, inertia 565.8396178629131.
# Initialization complete
# Iteration 31, inertia 557.868715909216.
# Initialization complete
# Iteration 32, inertia 561.3960646424161.
# Initialization complete
# Iteration 33, inertia 550.6796813414412.
# Initialization complete
# Iteration 34, inertia 557.0175176050857.
# Initialization complete
# Iteration 35, inertia 558.4095263188275.
# Initialization complete
# Iteration 36, inertia 550.3423760757032.
# Initialization complete
# Iteration 37, inertia 552.3699614770975.
# Initialization complete
# Iteration 38, inertia 569.8011595452231.
# Initialization complete
# Iteration 39, inertia 549.0661243618259.
# Initialization complete
# Iteration 40, inertia 556.3490665502875.
# Initialization complete
# Iteration 41, inertia 551.6869901024463.
# Initialization complete
# Iteration 42, inertia 554.4458987087676.
# Initialization complete
# Iteration 43, inertia 550.1751258241.
# Initialization complete
# Iteration 44, inertia 549.9655641357315.
# Initialization complete
# Iteration 45, inertia 556.4346374173075.
# Initialization complete
# Iteration 46, inertia 555.4247970444676.
# Initialization complete
# Iteration 47, inertia 550.0176409818964.
# Initialization complete
# Iteration 48, inertia 555.155476998067.
# Initialization complete
# Iteration 49, inertia 554.9528139030115.
# Initialization complete
# Iteration 50, inertia 552.801985793333.
# Initialization complete
# Iteration 51, inertia 549.8922603935221.
# Initialization complete
# Iteration 52, inertia 549.9910814630587.
# Initialization complete
# Iteration 53, inertia 557.4367143059097.
# Initialization complete
# Iteration 54, inertia 551.6659065422289.
# Initialization complete
# Iteration 55, inertia 561.7115634159474.
# Initialization complete
# Iteration 56, inertia 550.6418404011846.
# Initialization complete
# Iteration 57, inertia 550.436368154566.
# Initialization complete
# Iteration 58, inertia 564.8522901976661.
# Initialization complete
# Iteration 59, inertia 548.6164542479469.
# Initialization complete
# Iteration 60, inertia 563.69167922074.
# Initialization complete
# Iteration 61, inertia 572.3379855001815.
# Initialization complete
# Iteration 62, inertia 555.422514548779.
# Initialization complete
# Iteration 63, inertia 555.7730138662193.
# Initialization complete
# Iteration 64, inertia 549.2886807086433.
# Initialization complete
# Iteration 65, inertia 582.8362704002785.
# Initialization complete
# Iteration 66, inertia 564.1311374692021.
# Initialization complete
# Iteration 67, inertia 567.1263885210925.
# Initialization complete
# Iteration 68, inertia 566.839936181471.
# Initialization complete
# Iteration 69, inertia 555.160288777019.
# Initialization complete
# Iteration 70, inertia 562.0092696973259.
# Initialization complete
# Iteration 71, inertia 549.7826407974246.
# Initialization complete
# Iteration 72, inertia 555.3216180790622.
# Initialization complete
# Iteration 73, inertia 550.1429077903608.
# Initialization complete
# Iteration 74, inertia 555.0602917056721.
# Initialization complete
# Iteration 75, inertia 550.4783569514568.
# Initialization complete
# Iteration 76, inertia 563.3273878925937.
# Initialization complete
# Iteration 77, inertia 550.4022327863494.
# Initialization complete
# Iteration 78, inertia 549.1726457267731.
# Initialization complete
# Iteration 79, inertia 550.7957082096456.
# Initialization complete
# Iteration 80, inertia 570.4255713876055.
# Initialization complete
# Iteration 81, inertia 550.276478296286.
# Initialization complete
# Iteration 82, inertia 550.4274932986478.
# Initialization complete
# Iteration 83, inertia 589.1046845741547.
# Initialization complete
# Iteration 84, inertia 555.2635213000635.
# Initialization complete
# Iteration 85, inertia 549.9821222304136.
# Initialization complete
# Iteration 86, inertia 551.6364462403966.
# Initialization complete
# Iteration 87, inertia 561.99331510246.
# Initialization complete
# Iteration 88, inertia 548.5976010988677.
# Initialization complete
# Iteration 89, inertia 549.569571128022.
# Initialization complete
# Iteration 90, inertia 563.3187100302248.
# Initialization complete
# Iteration 91, inertia 548.3568430076966.
# Initialization complete
# Iteration 92, inertia 576.3181932731657.
# Initialization complete
# Iteration 93, inertia 548.9549589758592.
# Initialization complete
# Iteration 94, inertia 548.8294733589855.
# Initialization complete
# Iteration 95, inertia 563.5711381830109.
# Initialization complete
# Iteration 96, inertia 564.6234501384463.
# Initialization complete
# Iteration 97, inertia 550.6285530498473.
# Initialization complete
# Iteration 98, inertia 566.8663557004018.
# Initialization complete
# Iteration 99, inertia 573.0945936868513.
# Initialization complete
# Iteration 0, inertia 50.4722373701013.
# Initialization complete
# Iteration 1, inertia 42.23145555883815.
# Initialization complete
# Iteration 2, inertia 44.147931691117066.
# Initialization complete
# Iteration 3, inertia 42.37862889535194.
# Initialization complete
# Iteration 4, inertia 44.20742054517184.
# Initialization complete
# Iteration 5, inertia 43.082949439996014.
# Initialization complete
# Iteration 6, inertia 42.77919097972382.
# Initialization complete
# Iteration 7, inertia 44.745566453863276.
# Initialization complete
# Iteration 8, inertia 44.90206368576915.
# Initialization complete
# Iteration 9, inertia 45.556479925442446.
# Initialization complete
# Iteration 10, inertia 45.179768871279705.
# Initialization complete
# Iteration 11, inertia 43.53063866150313.
# Initialization complete
# Iteration 12, inertia 42.62910863229915.
# Initialization complete
# Iteration 13, inertia 47.100407262605785.
# Initialization complete
# Iteration 14, inertia 44.16485004109845.
# Initialization complete
# Iteration 15, inertia 46.14171992592509.
# Initialization complete
# Iteration 16, inertia 41.444877855781755.
# Initialization complete
# Iteration 17, inertia 42.67574350252468.
# Initialization complete
# Iteration 18, inertia 46.78448873514138.
# Initialization complete
# Iteration 19, inertia 47.760961938149634.
# Initialization complete
# Iteration 20, inertia 61.07305188585121.
# Initialization complete
# Iteration 21, inertia 44.035351406270166.
# Initialization complete
# Iteration 22, inertia 42.92412267783294.
# Initialization complete
# Iteration 23, inertia 42.1553077104533.
# Initialization complete
# Iteration 24, inertia 42.692313676323735.
# Initialization complete
# Iteration 25, inertia 42.48688286335373.
# Initialization complete
# Iteration 26, inertia 45.07904969509927.
# Initialization complete
# Iteration 27, inertia 42.791071371571135.
# Initialization complete
# Iteration 28, inertia 42.161792724450336.
# Initialization complete
# Iteration 29, inertia 45.72312079796333.
# Initialization complete
# Iteration 30, inertia 44.25872443241528.
# Initialization complete
# Iteration 31, inertia 48.136858314200154.
# Initialization complete
# Iteration 32, inertia 42.784610101835995.
# Initialization complete
# Iteration 33, inertia 46.95970137713125.
# Initialization complete
# Iteration 34, inertia 42.247605873742856.
# Initialization complete
# Iteration 35, inertia 43.757670012156495.
# Initialization complete
# Iteration 36, inertia 48.42867263406613.
# Initialization complete
# Iteration 37, inertia 43.127743172950446.
# Initialization complete
# Iteration 38, inertia 43.114163327787935.
# Initialization complete
# Iteration 39, inertia 44.245248068090305.
# Initialization complete
# Iteration 40, inertia 44.02260558553702.
# Initialization complete
# Iteration 41, inertia 42.783179963473586.
# Initialization complete
# Iteration 42, inertia 41.782603988663396.
# Initialization complete
# Iteration 43, inertia 42.040277358991744.
# Initialization complete
# Iteration 44, inertia 42.96392675146895.
# Initialization complete
# Iteration 45, inertia 51.22840166705792.
# Initialization complete
# Iteration 46, inertia 45.48812684717521.
# Initialization complete
# Iteration 47, inertia 46.23123042608796.
# Initialization complete
# Iteration 48, inertia 44.48555084063503.
# Initialization complete
# Iteration 49, inertia 43.64629926785291.
# Initialization complete
# Iteration 50, inertia 52.90406016984834.
# Initialization complete
# Iteration 51, inertia 45.86909363394369.
# Initialization complete
# Iteration 52, inertia 45.8597913217412.
# Initialization complete
# Iteration 53, inertia 46.8984663765206.
# Initialization complete
# Iteration 54, inertia 42.74007356455088.
# Initialization complete
# Iteration 55, inertia 43.88170624104417.
# Initialization complete
# Iteration 56, inertia 45.55428873606452.
# Initialization complete
# Iteration 57, inertia 49.04113119715298.
# Initialization complete
# Iteration 58, inertia 42.83322200949199.
# Initialization complete
# Iteration 59, inertia 42.441572217416194.
# Initialization complete
# Iteration 60, inertia 43.31852600758984.
# Initialization complete
# Iteration 61, inertia 67.42056397925464.
# Initialization complete
# Iteration 62, inertia 42.194194266220194.
# Initialization complete
# Iteration 63, inertia 43.15212427491966.
# Initialization complete
# Iteration 64, inertia 47.300456693583186.
# Initialization complete
# Iteration 65, inertia 42.44181194407477.
# Initialization complete
# Iteration 66, inertia 43.6181377148104.
# Initialization complete
# Iteration 67, inertia 44.08906091657144.
# Initialization complete
# Iteration 68, inertia 42.067396145009226.
# Initialization complete
# Iteration 69, inertia 43.43103931143189.
# Initialization complete
# Iteration 70, inertia 45.16031870955197.
# Initialization complete
# Iteration 71, inertia 43.3223857160291.
# Initialization complete
# Iteration 72, inertia 42.206723496141095.
# Initialization complete
# Iteration 73, inertia 50.297961069495216.
# Initialization complete
# Iteration 74, inertia 45.909043832450294.
# Initialization complete
# Iteration 75, inertia 43.971982906244605.
# Initialization complete
# Iteration 76, inertia 45.43797864001287.
# Initialization complete
# Iteration 77, inertia 45.51451195651464.
# Initialization complete
# Iteration 78, inertia 43.0962080341412.
# Initialization complete
# Iteration 79, inertia 47.262527904754165.
# Initialization complete
# Iteration 80, inertia 42.19239368281846.
# Initialization complete
# Iteration 81, inertia 42.25981506920739.
# Initialization complete
# Iteration 82, inertia 43.35893746215085.
# Initialization complete
# Iteration 83, inertia 42.10984608039948.
# Initialization complete
# Iteration 84, inertia 42.40538627240032.
# Initialization complete
# Iteration 85, inertia 49.21581193279742.
# Initialization complete
# Iteration 86, inertia 42.05028529594689.
# Initialization complete
# Iteration 87, inertia 42.1729208918628.
# Initialization complete
# Iteration 88, inertia 45.761063631407865.
# Initialization complete
# Iteration 89, inertia 42.55013280481256.
# Initialization complete
# Iteration 90, inertia 45.51565846992523.
# Initialization complete
# Iteration 91, inertia 46.67463721587211.
# Initialization complete
# Iteration 92, inertia 42.875897718069425.
# Initialization complete
# Iteration 93, inertia 45.29585753670351.
# Initialization complete
# Iteration 94, inertia 45.10511087727228.
# Initialization complete
# Iteration 95, inertia 41.90667616271807.
# Initialization complete
# Iteration 96, inertia 47.43213244847132.
# Initialization complete
# Iteration 97, inertia 46.31995769229033.
# Initialization complete
# Iteration 98, inertia 44.20350312851106.
# Initialization complete
# Iteration 99, inertia 47.83911737857876.
# Initialization complete
# Iteration 0, inertia 64.76028101415804.
# Initialization complete
# Iteration 1, inertia 64.3607760651898.
# Initialization complete
# Iteration 2, inertia 64.08852940465106.
# Initialization complete
# Iteration 3, inertia 63.8571466599316.
# Initialization complete
# Iteration 4, inertia 67.32171596530284.
# Initialization complete
# Iteration 5, inertia 63.5683045023702.
# Initialization complete
# Iteration 6, inertia 66.35411886123507.
# Initialization complete
# Iteration 7, inertia 67.56010886233169.
# Initialization complete
# Iteration 8, inertia 64.75542116194421.
# Initialization complete
# Iteration 9, inertia 65.65899985229683.
# Initialization complete
# Iteration 10, inertia 66.45915713588326.
# Initialization complete
# Iteration 11, inertia 66.68298537709263.
# Initialization complete
# Iteration 12, inertia 65.76102272301218.
# Initialization complete
# Iteration 13, inertia 63.951191051137656.
# Initialization complete
# Iteration 14, inertia 63.85962936819098.
# Initialization complete
# Iteration 15, inertia 64.01727597814786.
# Initialization complete
# Iteration 16, inertia 65.59445153027677.
# Initialization complete
# Iteration 17, inertia 66.74622233872077.
# Initialization complete
# Iteration 18, inertia 65.10411390317243.
# Initialization complete
# Iteration 19, inertia 64.11512339136871.
# Initialization complete
# Iteration 20, inertia 64.589516485513.
# Initialization complete
# Iteration 21, inertia 63.74530013397539.
# Initialization complete
# Iteration 22, inertia 65.9401486396734.
# Initialization complete
# Iteration 23, inertia 65.5548733867867.
# Initialization complete
# Iteration 24, inertia 65.43893857174375.
# Initialization complete
# Iteration 25, inertia 65.52537250393749.
# Initialization complete
# Iteration 26, inertia 64.86568300052836.
# Initialization complete
# Iteration 27, inertia 63.91999920651136.
# Initialization complete
# Iteration 28, inertia 65.08110486540603.
# Initialization complete
# Iteration 29, inertia 64.71155666816142.
# Initialization complete
# Iteration 30, inertia 63.75069903905445.
# Initialization complete
# Iteration 31, inertia 66.2486305741783.
# Initialization complete
# Iteration 32, inertia 63.644940841342034.
# Initialization complete
# Iteration 33, inertia 67.97572855494772.
# Initialization complete
# Iteration 34, inertia 64.83611061920101.
# Initialization complete
# Iteration 35, inertia 67.55265659773393.
# Initialization complete
# Iteration 36, inertia 64.81047204088657.
# Initialization complete
# Iteration 37, inertia 66.54638248037116.
# Initialization complete
# Iteration 38, inertia 67.6952783194542.
# Initialization complete
# Iteration 39, inertia 65.23196754218496.
# Initialization complete
# Iteration 40, inertia 64.83988292082981.
# Initialization complete
# Iteration 41, inertia 64.97356687394907.
# Initialization complete
# Iteration 42, inertia 66.2781239251282.
# Initialization complete
# Iteration 43, inertia 64.97954568435647.
# Initialization complete
# Iteration 44, inertia 65.35501833981016.
# Initialization complete
# Iteration 45, inertia 64.97328781603733.
# Initialization complete
# Iteration 46, inertia 64.53335878227256.
# Initialization complete
# Iteration 47, inertia 63.86688495612189.
# Initialization complete
# Iteration 48, inertia 63.62288575773162.
# Initialization complete
# Iteration 49, inertia 66.05784522881551.
# Initialization complete
# Iteration 50, inertia 67.280415657613.
# Initialization complete
# Iteration 51, inertia 67.45667214967273.
# Initialization complete
# Iteration 52, inertia 63.928386094167436.
# Initialization complete
# Iteration 53, inertia 64.82713664397951.
# Initialization complete
# Iteration 54, inertia 64.77243108237924.
# Initialization complete
# Iteration 55, inertia 64.04008535060593.
# Initialization complete
# Iteration 56, inertia 66.49763242459166.
# Initialization complete
# Iteration 57, inertia 66.95155441484036.
# Initialization complete
# Iteration 58, inertia 67.23906865104686.
# Initialization complete
# Iteration 59, inertia 64.73237016270038.
# Initialization complete
# Iteration 60, inertia 62.990806567569294.
# Initialization complete
# Iteration 61, inertia 65.87108411304118.
# Initialization complete
# Iteration 62, inertia 67.39128430567898.
# Initialization complete
# Iteration 63, inertia 63.886596604307016.
# Initialization complete
# Iteration 64, inertia 67.63242476533149.
# Initialization complete
# Iteration 65, inertia 64.97512044575565.
# Initialization complete
# Iteration 66, inertia 62.925808106921465.
# Initialization complete
# Iteration 67, inertia 64.83777530102229.
# Initialization complete
# Iteration 68, inertia 66.49521915840397.
# Initialization complete
# Iteration 69, inertia 64.86417869699896.
# Initialization complete
# Iteration 70, inertia 65.56962323372923.
# Initialization complete
# Iteration 71, inertia 64.64389906864278.
# Initialization complete
# Iteration 72, inertia 64.45970520131857.
# Initialization complete
# Iteration 73, inertia 63.88226953350356.
# Initialization complete
# Iteration 74, inertia 65.61457252802178.
# Initialization complete
# Iteration 75, inertia 63.098471553058445.
# Initialization complete
# Iteration 76, inertia 63.59827298188989.
# Initialization complete
# Iteration 77, inertia 65.37333303863116.
# Initialization complete
# Iteration 78, inertia 65.37590242415645.
# Initialization complete
# Iteration 79, inertia 64.96981663437425.
# Initialization complete
# Iteration 80, inertia 64.59104181783553.
# Initialization complete
# Iteration 81, inertia 64.67461403278696.
# Initialization complete
# Iteration 82, inertia 64.07260048150897.
# Initialization complete
# Iteration 83, inertia 63.430550757799296.
# Initialization complete
# Iteration 84, inertia 66.25846997040942.
# Initialization complete
# Iteration 85, inertia 69.30173840448055.
# Initialization complete
# Iteration 86, inertia 65.56653323039173.
# Initialization complete
# Iteration 87, inertia 64.4565588301341.
# Initialization complete
# Iteration 88, inertia 64.69684439936732.
# Initialization complete
# Iteration 89, inertia 64.87379122691475.
# Initialization complete
# Iteration 90, inertia 64.02657845429752.
# Initialization complete
# Iteration 91, inertia 66.70743199892652.
# Initialization complete
# Iteration 92, inertia 63.99419323188731.
# Initialization complete
# Iteration 93, inertia 66.31544723691667.
# Initialization complete
# Iteration 94, inertia 66.79638654694388.
# Initialization complete
# Iteration 95, inertia 66.31355053054097.
# Initialization complete
# Iteration 96, inertia 63.72762682576702.
# Initialization complete
# Iteration 97, inertia 66.16593978555636.
# Initialization complete
# Iteration 98, inertia 67.3334024798021.
# Initialization complete
# Iteration 99, inertia 64.2945132626634.
# Initialization complete
# Iteration 0, inertia 60.336672347499984.
# Initialization complete
# Iteration 1, inertia 60.058061368508305.
# Initialization complete
# Iteration 2, inertia 63.13090058550837.
# Initialization complete
# Iteration 3, inertia 60.58713568890444.
# Initialization complete
# Iteration 4, inertia 59.25302721605007.
# Initialization complete
# Iteration 5, inertia 62.20525154382017.
# Initialization complete
# Iteration 6, inertia 66.02176459661942.
# Initialization complete
# Iteration 7, inertia 59.53845605801837.
# Initialization complete
# Iteration 8, inertia 60.22105385098402.
# Initialization complete
# Iteration 9, inertia 60.59725768661431.
# Initialization complete
# Iteration 10, inertia 60.51260396398841.
# Initialization complete
# Iteration 11, inertia 58.413774929620416.
# Initialization complete
# Iteration 12, inertia 61.793107838327956.
# Initialization complete
# Iteration 13, inertia 63.14977137157122.
# Initialization complete
# Iteration 14, inertia 58.99237126086108.
# Initialization complete
# Iteration 15, inertia 63.728513735872426.
# Initialization complete
# Iteration 16, inertia 60.687540358298165.
# Initialization complete
# Iteration 17, inertia 61.51894497542992.
# Initialization complete
# Iteration 18, inertia 61.5878114439012.
# Initialization complete
# Iteration 19, inertia 58.5101258183594.
# Initialization complete
# Iteration 20, inertia 60.48919889730213.
# Initialization complete
# Iteration 21, inertia 62.36003836294458.
# Initialization complete
# Iteration 22, inertia 64.18984051766708.
# Initialization complete
# Iteration 23, inertia 60.21197846046432.
# Initialization complete
# Iteration 24, inertia 62.77429436945722.
# Initialization complete
# Iteration 25, inertia 73.63695369669878.
# Initialization complete
# Iteration 26, inertia 60.63069117427332.
# Initialization complete
# Iteration 27, inertia 61.90111313077833.
# Initialization complete
# Iteration 28, inertia 60.657525181180134.
# Initialization complete
# Iteration 29, inertia 58.802575557694624.
# Initialization complete
# Iteration 30, inertia 67.61924340669503.
# Initialization complete
# Iteration 31, inertia 63.330794660988914.
# Initialization complete
# Iteration 32, inertia 59.52324354709515.
# Initialization complete
# Iteration 33, inertia 62.81087027475293.
# Initialization complete
# Iteration 34, inertia 63.029668301277425.
# Initialization complete
# Iteration 35, inertia 63.96673592901857.
# Initialization complete
# Iteration 36, inertia 64.06819521742501.
# Initialization complete
# Iteration 37, inertia 58.23723745130273.
# Initialization complete
# Iteration 38, inertia 60.92307368378661.
# Initialization complete
# Iteration 39, inertia 64.62618173749486.
# Initialization complete
# Iteration 40, inertia 62.68650497856278.
# Initialization complete
# Iteration 41, inertia 59.69603473534717.
# Initialization complete
# Iteration 42, inertia 58.538598790680396.
# Initialization complete
# Iteration 43, inertia 63.48862669380344.
# Initialization complete
# Iteration 44, inertia 60.58321714805915.
# Initialization complete
# Iteration 45, inertia 60.50115436643776.
# Initialization complete
# Iteration 46, inertia 61.192961354698895.
# Initialization complete
# Iteration 47, inertia 58.74750997706296.
# Initialization complete
# Iteration 48, inertia 63.13014889360582.
# Initialization complete
# Iteration 49, inertia 66.08029302360757.
# Initialization complete
# Iteration 50, inertia 61.24456437938245.
# Initialization complete
# Iteration 51, inertia 57.74857575462973.
# Initialization complete
# Iteration 52, inertia 63.566248012253055.
# Initialization complete
# Iteration 53, inertia 59.022621306129125.
# Initialization complete
# Iteration 54, inertia 71.56524709165278.
# Initialization complete
# Iteration 55, inertia 64.56876265904279.
# Initialization complete
# Iteration 56, inertia 63.501646617053126.
# Initialization complete
# Iteration 57, inertia 59.54639855844897.
# Initialization complete
# Iteration 58, inertia 59.33596948470223.
# Initialization complete
# Iteration 59, inertia 88.52280675491001.
# Initialization complete
# Iteration 60, inertia 61.88559637888822.
# Initialization complete
# Iteration 61, inertia 60.1265905303497.
# Initialization complete
# Iteration 62, inertia 60.21197846046432.
# Initialization complete
# Iteration 63, inertia 61.15603829712576.
# Initialization complete
# Iteration 64, inertia 61.88693320275554.
# Initialization complete
# Iteration 65, inertia 61.04587212735515.
# Initialization complete
# Iteration 66, inertia 67.15926381947087.
# Initialization complete
# Iteration 67, inertia 60.53821541807953.
# Initialization complete
# Iteration 68, inertia 59.28507853746834.
# Initialization complete
# Iteration 69, inertia 63.40115267973255.
# Initialization complete
# Iteration 70, inertia 58.85772374887492.
# Initialization complete
# Iteration 71, inertia 60.749679558126616.
# Initialization complete
# Iteration 72, inertia 63.906423300110134.
# Initialization complete
# ...
# Initialization complete
# Iteration 57, inertia 27.615355672553477.
# Initialization complete
# Iteration 58, inertia 29.129042745355903.
# Initialization complete
# Iteration 59, inertia 30.242271100489774.
# Initialization complete
# Iteration 60, inertia 27.62484092396302.
# Initialization complete
# Iteration 61, inertia 26.656236822159993.
# Initialization complete
# Iteration 62, inertia 28.4949855142482.
# Initialization complete
# Iteration 63, inertia 29.15989339994009.
# Initialization complete
# Iteration 64, inertia 26.802032854328445.
# Initialization complete
# Iteration 65, inertia 27.868085899569536.
# Initialization complete
# Iteration 66, inertia 27.42704430410693.
# Initialization complete
# Iteration 67, inertia 28.538909161984677.
# Initialization complete
# Iteration 68, inertia 27.547074360999602.
# Initialization complete
# Iteration 69, inertia 27.995575819813368.
# Initialization complete
# Iteration 70, inertia 26.797878115570953.
# Initialization complete
# Iteration 71, inertia 28.54137300488175.
# Initialization complete
# Iteration 72, inertia 28.129173999784015.
# Initialization complete
# Iteration 73, inertia 28.47193378053896.
# Initialization complete
# Iteration 74, inertia 27.96597064976288.
# Initialization complete
# Iteration 75, inertia 28.44155977248765.
# Initialization complete
# Iteration 76, inertia 29.90695314593698.
# Initialization complete
# Iteration 77, inertia 26.905140902074436.
# Initialization complete
# Iteration 78, inertia 27.87538348719258.
# Initialization complete
# Iteration 79, inertia 28.993950849453725.
# Initialization complete
# Iteration 80, inertia 27.934338545648416.
# Initialization complete
# Iteration 81, inertia 27.64659045919103.
# Initialization complete
# Iteration 82, inertia 27.161490403113064.
# Initialization complete
# Iteration 83, inertia 28.466569330979752.
# Initialization complete
# Iteration 84, inertia 27.97340150220272.
# Initialization complete
# Iteration 85, inertia 27.19616998807724.
# Initialization complete
# Iteration 86, inertia 28.227620546923617.
# Initialization complete
# Iteration 87, inertia 27.092122927219904.
# Initialization complete
# Iteration 88, inertia 26.353894866819797.
# Initialization complete
# Iteration 89, inertia 28.63337592517415.
# Initialization complete
# Iteration 90, inertia 27.57704931257925.
# Initialization complete
# Iteration 91, inertia 27.389960154882488.
# Initialization complete
# Iteration 92, inertia 28.007544758591706.
# Initialization complete
# Iteration 93, inertia 28.672120788272764.
# Initialization complete
# Iteration 94, inertia 28.407777223721126.
# Initialization complete
# Iteration 95, inertia 27.432752924661955.
# Initialization complete
# Iteration 96, inertia 27.450449537210076.
# Initialization complete
# Iteration 97, inertia 29.25599365495961.
# Initialization complete
# Iteration 98, inertia 27.249563048154116.
# Initialization complete
# Iteration 99, inertia 26.951846302611855.
# Initialization complete
# Iteration 0, inertia 11.814410958771663.
# Initialization complete
# Iteration 1, inertia 12.395614945835835.
# Initialization complete
# Iteration 2, inertia 12.134005653748563.
# Initialization complete
# Iteration 3, inertia 12.575206816326716.
# Initialization complete
# Iteration 4, inertia 12.253570979563808.
# Initialization complete
# Iteration 5, inertia 13.575918474510761.
# Initialization complete
# Iteration 6, inertia 12.158897184004903.
# Initialization complete
# Iteration 7, inertia 19.542040914295928.
# Initialization complete
# Iteration 8, inertia 13.504125146895507.
# Initialization complete
# Iteration 9, inertia 12.031015883672115.
# Initialization complete
# Iteration 10, inertia 12.408258510013486.
# Initialization complete
# Iteration 11, inertia 12.985250580697869.
# Initialization complete
# Iteration 12, inertia 13.542730460737136.
# Initialization complete
# Iteration 13, inertia 12.550661540747772.
# Initialization complete
# Iteration 14, inertia 14.045055288025186.
# Initialization complete
# Iteration 15, inertia 12.798789328530805.
# Initialization complete
# Iteration 16, inertia 13.770171690748004.
# Initialization complete
# Iteration 17, inertia 12.67851064013131.
# Initialization complete
# Iteration 18, inertia 12.610093957566054.
# Initialization complete
# Iteration 19, inertia 12.36465887126396.
# Initialization complete
# Iteration 20, inertia 17.80743422472165.
# Initialization complete
# Iteration 21, inertia 12.403080960213277.
# Initialization complete
# Iteration 22, inertia 11.962689679804289.
# Initialization complete
# Iteration 23, inertia 18.22834212992061.
# Initialization complete
# Iteration 24, inertia 11.862009837608287.
# Initialization complete
# Iteration 25, inertia 11.96483376608909.
# Initialization complete
# Iteration 26, inertia 12.058470207280326.
# Initialization complete
# Iteration 27, inertia 11.820579571397364.
# Initialization complete
# Iteration 28, inertia 12.550363043146223.
# Initialization complete
# Iteration 29, inertia 12.332627996863184.
# Initialization complete
# Iteration 30, inertia 19.70332559515862.
# Initialization complete
# Iteration 31, inertia 12.482383737588808.
# Initialization complete
# Iteration 32, inertia 13.599880301204454.
# Initialization complete
# Iteration 33, inertia 11.985923492398545.
# Initialization complete
# Iteration 34, inertia 12.298556332934371.
# Initialization complete
# Iteration 35, inertia 12.727143377535288.
# Initialization complete
# Iteration 36, inertia 13.908800236369206.
# Initialization complete
# Iteration 37, inertia 12.279613609999164.
# Initialization complete
# Iteration 38, inertia 11.844641551064417.
# Initialization complete
# Iteration 39, inertia 13.709719460027888.
# Initialization complete
# Iteration 40, inertia 11.875813510279134.
# Initialization complete
# Iteration 41, inertia 12.660390625116552.
# Initialization complete
# Iteration 42, inertia 12.406625920401698.
# Initialization complete
# Iteration 43, inertia 12.22788233632794.
# Initialization complete
# Iteration 44, inertia 12.081691084972409.
# Initialization complete
# Iteration 45, inertia 16.911513992340378.
# Initialization complete
# Iteration 46, inertia 12.090721802121653.
# Initialization complete
# Iteration 47, inertia 12.034197539583264.
# Initialization complete
# Iteration 48, inertia 12.052751932083769.
# Initialization complete
# Iteration 49, inertia 12.273237303767349.
# Initialization complete
# Iteration 50, inertia 12.70343766806582.
# Initialization complete
# Iteration 51, inertia 12.275961622921987.
# Initialization complete
# Iteration 52, inertia 12.671822608764646.
# Initialization complete
# Iteration 53, inertia 12.940487346800541.
# Initialization complete
# Iteration 54, inertia 13.30290427033653.
# Initialization complete
# Iteration 55, inertia 12.249933483613237.
# Initialization complete
# Iteration 56, inertia 12.218937238202802.
# Initialization complete
# Iteration 57, inertia 12.788854759092676.
# Initialization complete
# Iteration 58, inertia 19.277342259427986.
# Initialization complete
# Iteration 59, inertia 12.866207288279487.
# Initialization complete
# Iteration 60, inertia 12.146070892952412.
# Initialization complete
# Iteration 61, inertia 12.49318845291494.
# Initialization complete
# Iteration 62, inertia 12.444480363128196.
# Initialization complete
# Iteration 63, inertia 12.171837306907737.
# Initialization complete
# Iteration 64, inertia 12.984712375625026.
# Initialization complete
# Iteration 65, inertia 12.67075339927651.
# Initialization complete
# Iteration 66, inertia 11.821723255273302.
# Initialization complete
# Iteration 67, inertia 12.481452945136656.
# Initialization complete
# Iteration 68, inertia 17.473862633385128.
# Initialization complete
# Iteration 69, inertia 12.38629405925214.
# Initialization complete
# Iteration 70, inertia 12.474312283154024.
# Initialization complete
# Iteration 71, inertia 12.390635336441736.
# Initialization complete
# Iteration 72, inertia 12.460510490934158.
# Initialization complete
# Iteration 73, inertia 12.527710358537963.
# Initialization complete
# Iteration 74, inertia 12.454752205516275.
# Initialization complete
# Iteration 75, inertia 12.480095854279828.
# Initialization complete
# Iteration 76, inertia 12.102646765504634.
# Initialization complete
# Iteration 77, inertia 12.928175726178356.
# Initialization complete
# Iteration 78, inertia 12.287303434649136.
# Initialization complete
# Iteration 79, inertia 13.337250033205738.
# Initialization complete
# Iteration 80, inertia 12.322145873322217.
# Initialization complete
# Iteration 81, inertia 12.91990604466439.
# Initialization complete
# Iteration 82, inertia 12.184746025567694.
# Initialization complete
# Iteration 83, inertia 11.91173847730531.
# Initialization complete
# Iteration 84, inertia 12.373601592442927.
# Initialization complete
# Iteration 85, inertia 12.641492263446114.
# Initialization complete
# Iteration 86, inertia 12.682069979782657.
# Initialization complete
# Iteration 87, inertia 12.132480137180739.
# Initialization complete
# Iteration 88, inertia 12.549259684419187.
# Initialization complete
# Iteration 89, inertia 12.548983067503247.
# Initialization complete
# Iteration 90, inertia 12.717498418099911.
# Initialization complete
# Iteration 91, inertia 12.020177110083697.
# Initialization complete
# Iteration 92, inertia 12.124326348568506.
# Initialization complete
# Iteration 93, inertia 11.944358145643623.
# Initialization complete
# Iteration 94, inertia 12.229293386731005.
# Initialization complete
# Iteration 95, inertia 12.278473110144478.
# Initialization complete
# Iteration 96, inertia 13.124619862598198.
# Initialization complete
# Iteration 97, inertia 12.146070892952412.
# Initialization complete
# Iteration 98, inertia 12.370486193667933.
# Initialization complete
# Iteration 99, inertia 12.116278002077014.
# Initialization complete
# Iteration 0, inertia 25.78250440755181.
# Initialization complete
# Iteration 1, inertia 27.94376630688231.
# Initialization complete
# Iteration 2, inertia 25.1197981729545.
# Initialization complete
# Iteration 3, inertia 26.0995107487701.
# Initialization complete
# Iteration 4, inertia 26.894232950853432.
# Initialization complete
# Iteration 5, inertia 25.462078043799167.
# Initialization complete
# Iteration 6, inertia 25.342330385937043.
# Initialization complete
# Iteration 7, inertia 25.370440686659066.
# Initialization complete
# Iteration 8, inertia 26.460109771459685.
# Initialization complete
# Iteration 9, inertia 24.957159130665442.
# Initialization complete
# Iteration 10, inertia 25.099509124892407.
# Initialization complete
# Iteration 11, inertia 25.707326375740404.
# Initialization complete
# Iteration 12, inertia 24.948091233044707.
# Initialization complete
# Iteration 13, inertia 25.493647566968406.
# Initialization complete
# Iteration 14, inertia 25.376696057758593.
# Initialization complete
# Iteration 15, inertia 25.621519088513494.
# Initialization complete
# Iteration 16, inertia 25.124956189603765.
# Initialization complete
# Iteration 17, inertia 25.922924557149383.
# Initialization complete
# Iteration 18, inertia 25.538675260344547.
# Initialization complete
# Iteration 19, inertia 25.030789951125143.
# Initialization complete
# Iteration 20, inertia 25.65479592240412.
# Initialization complete
# Iteration 21, inertia 25.837392454688484.
# Initialization complete
# Iteration 22, inertia 25.007743864682894.
# Initialization complete
# Iteration 23, inertia 25.317011719034895.
# Initialization complete
# Iteration 24, inertia 25.252822787836077.
# Initialization complete
# Iteration 25, inertia 25.46629789257686.
# Initialization complete
# Iteration 26, inertia 25.126622691074143.
# Initialization complete
# Iteration 27, inertia 26.93785050220481.
# Initialization complete
# Iteration 28, inertia 25.330486738284392.
# Initialization complete
# Iteration 29, inertia 25.57490850570919.
# Initialization complete
# Iteration 30, inertia 26.491278130483902.
# Initialization complete
# Iteration 31, inertia 25.13137635965928.
# Initialization complete
# Iteration 32, inertia 26.035958875211318.
# Initialization complete
# Iteration 33, inertia 24.905252790251083.
# Initialization complete
# Iteration 34, inertia 25.447247744113355.
# Initialization complete
# Iteration 35, inertia 25.30230151770263.
# Initialization complete
# Iteration 36, inertia 25.699129981930383.
# Initialization complete
# Iteration 37, inertia 27.78337838225762.
# Initialization complete
# Iteration 38, inertia 25.50847987472531.
# Initialization complete
# Iteration 39, inertia 25.68077738013089.
# Initialization complete
# Iteration 40, inertia 28.591561079977193.
# Initialization complete
# Iteration 41, inertia 24.890747184132877.
# Initialization complete
# Iteration 42, inertia 25.753537885343235.
# Initialization complete
# Iteration 43, inertia 25.157580302415763.
# Initialization complete
# Iteration 44, inertia 25.035723654021396.
# Initialization complete
# Iteration 45, inertia 26.46778486809032.
# Initialization complete
# Iteration 46, inertia 26.485984429307052.
# Initialization complete
# Iteration 47, inertia 26.881756666389307.
# Initialization complete
# Iteration 48, inertia 25.163453237504967.
# Initialization complete
# Iteration 49, inertia 25.16906368434512.
# Initialization complete
# Iteration 50, inertia 27.509848172518684.
# Initialization complete
# Iteration 51, inertia 27.47127621367576.
# Initialization complete
# Iteration 52, inertia 25.770758687468017.
# Initialization complete
# Iteration 53, inertia 24.94562649234524.
# Initialization complete
# Iteration 54, inertia 25.00281542003792.
# Initialization complete
# Iteration 55, inertia 28.38907238686799.
# Initialization complete
# Iteration 56, inertia 26.212538354376985.
# Initialization complete
# Iteration 57, inertia 25.372835373473546.
# Initialization complete
# Iteration 58, inertia 25.270927826397596.
# Initialization complete
# Iteration 59, inertia 25.724736745724368.
# Initialization complete
# Iteration 60, inertia 26.074622133038176.
# Initialization complete
# Iteration 61, inertia 25.338257406822645.
# Initialization complete
# Iteration 62, inertia 26.336926313133674.
# Initialization complete
# Iteration 63, inertia 25.731028422561536.
# Initialization complete
# Iteration 64, inertia 25.20466225454383.
# Initialization complete
# Iteration 65, inertia 25.129870618880034.
# Initialization complete
# Iteration 66, inertia 29.417899240498897.
# Initialization complete
# Iteration 67, inertia 26.35173223427061.
# Initialization complete
# Iteration 68, inertia 25.63163113760787.
# Initialization complete
# Iteration 69, inertia 26.94115179647521.
# Initialization complete
# Iteration 70, inertia 25.417118806662213.
# Initialization complete
# Iteration 71, inertia 25.424096785556912.
# Initialization complete
# Iteration 72, inertia 27.982422586753813.
# Initialization complete
# Iteration 73, inertia 25.569904309670136.
# Initialization complete
# Iteration 74, inertia 25.350731933288362.
# Initialization complete
# Iteration 75, inertia 27.040222414468996.
# Initialization complete
# Iteration 76, inertia 25.121050310731405.
# Initialization complete
# Iteration 77, inertia 27.806165817271445.
# Initialization complete
# Iteration 78, inertia 27.256281808639653.
# Initialization complete
# Iteration 79, inertia 26.76532593702913.
# Initialization complete
# Iteration 80, inertia 25.19943096563847.
# Initialization complete
# Iteration 81, inertia 24.937854747638138.
# Initialization complete
# Iteration 82, inertia 25.488863429444066.
# Initialization complete
# Iteration 83, inertia 27.5131979934237.
# Initialization complete
# Iteration 84, inertia 25.304573166826454.
# Initialization complete
# Iteration 85, inertia 26.093231694806406.
# Initialization complete
# Iteration 86, inertia 25.11187658655419.
# Initialization complete
# Iteration 87, inertia 25.014832194395467.
# Initialization complete
# Iteration 88, inertia 25.651648612576523.
# Initialization complete
# Iteration 89, inertia 25.060300105447794.
# Initialization complete
# Iteration 90, inertia 26.374257198159157.
# Initialization complete
# Iteration 91, inertia 24.755148412122708.
# Initialization complete
# Iteration 92, inertia 29.067567031410476.
# Initialization complete
# Iteration 93, inertia 27.55517883843876.
# Initialization complete
# Iteration 94, inertia 24.84754373013648.
# Initialization complete
# Iteration 95, inertia 25.892738136581084.
# Initialization complete
# Iteration 96, inertia 26.28957470858299.
# Initialization complete
# Iteration 97, inertia 27.46316820880224.
# Initialization complete
# Iteration 98, inertia 25.004241602279432.
# Initialization complete
# Iteration 99, inertia 24.894030150086706.
# Complete!
